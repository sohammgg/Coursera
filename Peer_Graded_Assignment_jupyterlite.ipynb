# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
boston_df=pd.read_csv('boston_housing.csv')

boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
# Box plot for MEDV 
plt.boxplot(boston_df['MEDV'])
plt.title('MDEV Box plot')
# Out:
# Text(0.5, 1.0, 'MDEV Box plot')

# %%
# Bar plot for CHAS
plt.bar(boston_df.index, boston_df['CHAS'])
# Out:
# <BarContainer object of 506 artists>

# %%
# Boxplot of MEDV vs AGE 
bins = [0, 35, 70, float('inf')]
labels = ['35 years and younger', 'Between 30 and 75 years', '70 and older']

boston_df['Age Group'] = pd.cut(boston_df['AGE'], bins=bins, labels=labels, right=False )

sns.boxplot(x='Age Group', y='MEDV', data=boston_df)

plt.title('MEDV vs AGE ')
plt.xlabel('Age Group')
plt.ylabel('MEDV')
plt.show()

# %%
# Scatter plot between NOX and INDUS 
sns.scatterplot(x='NOX', y='INDUS', data=boston_df)

plt.title('Effect of Nitric Oxide on non-retail business acres/town')
plt.xlabel('NOX')
plt.ylabel('INDUS')

plt.show()

# %%
# Histogram for PTRATIO
sns.histplot(data=boston_df, x='PTRATIO')
plt.title('Histogram of Pupil-to-Teacher Ratio')
plt.xlabel('Pupil-to-Teacher Ratio')
plt.ylabel('Frequency')
plt.show()
